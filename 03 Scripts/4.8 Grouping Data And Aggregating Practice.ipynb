# %% [markdown]
# <H1>1.Importing Libraries</H1>

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# <H1>Import Data Files</H1>

# %%
# Creating Path
path = r'C:\Users\supri\Desktop\Supriya\DataAnalysis\Project\Data Immersion\Achievement 1-2\Instacart_Basket_Analysis'

# %%
# Importing orders_products_merged_derived.pkl File
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data' , 'ords_prods_merged_derived.pkl'))

# %%
# create a subset
df=ords_prods_merge[:1000000]

# %%
#Check output
df.shape
# Out:
# (1000000, 21)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0             0   2539329        1    prior             1
# 1             0   2539329        1    prior             1
# 2             0   2539329        1    prior             1
# 3             0   2539329        1    prior             1
# 4             0   2539329        1    prior             1
# 5             1   2398795        1    prior             2
# 6             1   2398795        1    prior             2
# 7             1   2398795        1    prior             2
# 8             1   2398795        1    prior             2
# 9             1   2398795        1    prior             2
#
#    orders_days_of_week  order_hour_of_day  days_since_prior_order  \
# 0                    2                  8                     NaN
# 1                    2                  8                     NaN
# 2                    2                  8                     NaN
# 3                    2                  8                     NaN
# 4                    2                  8                     NaN
# 5                    3                  7                    15.0
# 6                    3                  7                    15.0
# 7                    3                  7                    15.0
# 8                    3                  7                    15.0
# 9                    3                  7                    15.0
#
#    first_time_customers  product_id  ...  reordered  \
# 0                  True         196  ...          0
# 1                  True       14084  ...          0
# 2                  True       12427  ...          0
# 3                  True       26088  ...          0
# 4                  True       26405  ...          0
# 5                 False         196  ...          1
# 6                 False       10258  ...          0
# 7                 False       12427  ...          1
# 8                 False       13176  ...          0
# 9                 False       26088  ...          1
#
#                               product_name aisle_id  department_id  prices  \
# 0                                     Soda       77              7     9.0
# 1  Organic Unsweetened Vanilla Almond Milk       91             16    12.5
# 2                      Original Beef Jerky       23             19     4.4
# 3               Aged White Cheddar Popcorn       23             19     4.7
# 4         XL Pick-A-Size Paper Towel Rolls       54             17     1.0
# 5                                     Soda       77              7     9.0
# 6                               Pistachios      117             19     3.0
# 7                      Original Beef Jerky       23             19     4.4
# 8                   Bag of Organic Bananas       24              4    10.3
# 9               Aged White Cheddar Popcorn       23             19     4.7
#
#    match    price_range_loc     busiest_day    busiest_days  \
# 0   both  Mid-range product  Regularly busy  Regularly busy
# 1   both  Mid-range product  Regularly busy  Regularly busy
# 2   both  Low-range product  Regularly busy  Regularly busy
# 3   both  Low-range product  Regularly busy  Regularly busy
# 4   both  Low-range product  Regularly busy  Regularly busy
# 5   both  Mid-range product  Regularly busy    Slowest Days
# 6   both  Low-range product  Regularly busy    Slowest Days
# 7   both  Low-range product  Regularly busy    Slowest Days
# 8   both  Mid-range product  Regularly busy    Slowest Days
# 9   both  Low-range product  Regularly busy    Slowest Days
#
#   busiest_period_of_day
# 0        Average orders
# 1        Average orders
# 2        Average orders
# 3        Average orders
# 4        Average orders
# 5        Average orders
# 6        Average orders
# 7        Average orders
# 8        Average orders
# 9        Average orders
#
# [10 rows x 21 columns]

# %% [markdown]
# <H3>2. Grouping Data with Pandas</H3>

# %%
# Grouping data in pandas follows a set of logical steps
# First, split the data into groups based on given criteria
# Next, apply a function to these groups
# Lastly, combine the results to see what was created

# %%
# The 'groupby()' function will group a given dataframe by a given column
df.groupby('product_name')

# %%
# The function created a pandas object
# But, the output is not visible yet
# It needs next step, like aggregating the data or applying a function, before seeing the results
# groupby() should always be used as part of a series of steps

# %% [markdown]
# <H3>3.Aggregating Data with agg()</H3>

# %%
# Aggregating functions create summaries of selected columns and store these summary values in new columns
# These summaries usually take the form of a descriptive statistic

# %%
# The 'agg()' function is used for aggregation
# It is used to produce a single descriptive statistic for the 'order_number' column
# If you were to calculate the mean of the 'order_number' column grouped by the 'department_id' column, you can compare user orders in each department
# 'order_number' refers to the number of orders placed by a given user
# The process is as follows:
# 1. Split the data into groups based on 'department_id'
# 2. Apply the agg() function to each group to obtain the mean values for the 'order_number' column
df.groupby('department_id').agg({'order_number':['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# The groupby() function is assigned to the df dataframe, creating a pandas object for the 'department_id'
# The agg() function is applied to this object, returning the mean of the given column 'order_id'
# The result is the average number of orders per user for each department id

# %%
# The aggregation can be conducted without the use of the agg() function using the mean()
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %%
# Observation -The difference in syntax between the two methods:
# 1. When using agg(), put the column you want to aggregate inside the parenthesis of the agg()
# 2. When using mean(), simply index the column with square brackets, then follow it with the function you want to use after the dot

# %% [markdown]
# <H4>Perform multiple aggregations at once</H4>

# %%
# You can perform multiple aggregations at once
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# <H4>4. Aggregating Data with transform()</H4>

# %%
#Loyal customers frequently return to use the service or buy products.
#To help the business strategy team implement a bonus program, we'll identify these customers using the transform() function to find the maximum frequency of order_number. 
#Then, we'll use loc() to flag them as 'loyal' or not.

# %%
# Flag Criteria:
# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a 'Loyal customer'
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a 'Regular customer'
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a 'New customer'

# %%
# Steps
# 1. Split the data in groups based on the 'user_id' column
# 2. Apply the transform() function on the 'order_number' column to generate the maximum orders for each user
# 3. Create a new column, 'max_order,' into which you'll place the results of your aggregation
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform('max')

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
#
#     orders_days_of_week  order_hour_of_day  days_since_prior_order  \
# 0                     2                  8                     NaN
# 1                     2                  8                     NaN
# 2                     2                  8                     NaN
# 3                     2                  8                     NaN
# 4                     2                  8                     NaN
# 5                     3                  7                    15.0
# 6                     3                  7                    15.0
# 7                     3                  7                    15.0
# 8                     3                  7                    15.0
# 9                     3                  7                    15.0
# 10                    3                  7                    15.0
# 11                    3                 12                    21.0
# 12                    3                 12                    21.0
# 13                    3                 12                    21.0
# 14                    3                 12                    21.0
#
#     first_time_customers  product_id  ...  \
# 0                   True         196  ...
# 1                   True       14084  ...
# 2                   True       12427  ...
# 3                   True       26088  ...
# 4                   True       26405  ...
# 5                  False         196  ...
# 6                  False       10258  ...
# 7                  False       12427  ...
# 8                  False       13176  ...
# 9                  False       26088  ...
# 10                 False       13032  ...
# 11                 False         196  ...
# 12                 False       12427  ...
# 13                 False       10258  ...
# 14                 False       25133  ...
#
#                                product_name  aisle_id department_id  prices  \
# 0                                      Soda        77             7     9.0
# 1   Organic Unsweetened Vanilla Almond Milk        91            16    12.5
# 2                       Original Beef Jerky        23            19     4.4
# 3                Aged White Cheddar Popcorn        23            19     4.7
# 4          XL Pick-A-Size Paper Towel Rolls        54            17     1.0
# 5                                      Soda        77             7     9.0
# 6                                Pistachios       117            19     3.0
# 7                       Original Beef Jerky        23            19     4.4
# 8                    Bag of Organic Bananas        24             4    10.3
# 9                Aged White Cheddar Popcorn        23            19     4.7
# 10                    Cinnamon Toast Crunch       121            14     4.0
# 11                                     Soda        77             7     9.0
# 12                      Original Beef Jerky        23            19     4.4
# 13                               Pistachios       117            19     3.0
# 14                    Organic String Cheese        21            16     8.6
#
#     match    price_range_loc     busiest_day    busiest_days  \
# 0    both  Mid-range product  Regularly busy  Regularly busy
# 1    both  Mid-range product  Regularly busy  Regularly busy
# 2    both  Low-range product  Regularly busy  Regularly busy
# 3    both  Low-range product  Regularly busy  Regularly busy
# 4    both  Low-range product  Regularly busy  Regularly busy
# 5    both  Mid-range product  Regularly busy    Slowest Days
# 6    both  Low-range product  Regularly busy    Slowest Days
# 7    both  Low-range product  Regularly busy    Slowest Days
# 8    both  Mid-range product  Regularly busy    Slowest Days
# 9    both  Low-range product  Regularly busy    Slowest Days
# 10   both  Low-range product  Regularly busy    Slowest Days
# 11   both  Mid-range product  Regularly busy    Slowest Days
# 12   both  Low-range product  Regularly busy    Slowest Days
# 13   both  Low-range product  Regularly busy    Slowest Days
# 14   both  Mid-range product  Regularly busy    Slowest Days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2         Average orders        10
# 3         Average orders        10
# 4         Average orders        10
# 5         Average orders        10
# 6         Average orders        10
# 7         Average orders        10
# 8         Average orders        10
# 9         Average orders        10
# 10        Average orders        10
# 11           Most orders        10
# 12           Most orders        10
# 13           Most orders        10
# 14           Most orders        10
#
# [15 rows x 22 columns]

# %%
# Now we have a new 'max_order' column in our dataframe
# Each value in this column corresponds to the maximum number of orders made by each user id

# %%
# You can check the output by printing the head of the dataframe with an argument of, say 100
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# ..           ...       ...      ...      ...           ...
# 95            14    738281        2    prior             4
# 96            15   1673511        2    prior             5
# 97            15   1673511        2    prior             5
# 98            15   1673511        2    prior             5
# 99            15   1673511        2    prior             5
#
#     orders_days_of_week  order_hour_of_day  days_since_prior_order  \
# 0                     2                  8                     NaN
# 1                     2                  8                     NaN
# 2                     2                  8                     NaN
# 3                     2                  8                     NaN
# 4                     2                  8                     NaN
# ..                  ...                ...                     ...
# 95                    2                 10                     8.0
# 96                    3                 11                     8.0
# 97                    3                 11                     8.0
# 98                    3                 11                     8.0
# 99                    3                 11                     8.0
#
#     first_time_customers  product_id  ...  \
# 0                   True         196  ...
# 1                   True       14084  ...
# 2                   True       12427  ...
# 3                   True       26088  ...
# 4                   True       26405  ...
# ..                   ...         ...  ...
# 95                 False       21150  ...
# 96                 False       47144  ...
# 97                 False        5322  ...
# 98                 False       17224  ...
# 99                 False       38656  ...
#
#                                          product_name  aisle_id department_id  \
# 0                                                Soda        77             7
# 1             Organic Unsweetened Vanilla Almond Milk        91            16
# 2                                 Original Beef Jerky        23            19
# 3                          Aged White Cheddar Popcorn        23            19
# 4                    XL Pick-A-Size Paper Towel Rolls        54            17
# ..                                                ...       ...           ...
# 95                            Fire Grilled Steak Bowl        38             1
# 96     Unsweetened Original Almond Breeze Almond Milk        91            16
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3            19
# 98                   Oats & Honey Gluten Free Granola         3            19
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3            19
#
#     prices  match    price_range_loc     busiest_day    busiest_days  \
# 0      9.0   both  Mid-range product  Regularly busy  Regularly busy
# 1     12.5   both  Mid-range product  Regularly busy  Regularly busy
# 2      4.4   both  Low-range product  Regularly busy  Regularly busy
# 3      4.7   both  Low-range product  Regularly busy  Regularly busy
# 4      1.0   both  Low-range product  Regularly busy  Regularly busy
# ..     ...    ...                ...             ...             ...
# 95     5.9   both  Mid-range product  Regularly busy  Regularly busy
# 96    14.0   both  Mid-range product  Regularly busy    Slowest Days
# 97     2.9   both  Low-range product  Regularly busy    Slowest Days
# 98     1.6   both  Low-range product  Regularly busy    Slowest Days
# 99     3.4   both  Low-range product  Regularly busy    Slowest Days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2         Average orders        10
# 3         Average orders        10
# 4         Average orders        10
# ..                   ...       ...
# 95           Most orders        14
# 96           Most orders        14
# 97           Most orders        14
# 98           Most orders        14
# 99           Most orders        14
#
# [100 rows x 22 columns]

# %%
# However, the current settings won't allow you to see all 100
# This can be changed via the following code:
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
# 15             2    473747        1    prior             3
# 16             3   2254736        1    prior             4
# 17             3   2254736        1    prior             4
# 18             3   2254736        1    prior             4
# 19             3   2254736        1    prior             4
# 20             3   2254736        1    prior             4
# 21             4    431534        1    prior             5
# 22             4    431534        1    prior             5
# 23             4    431534        1    prior             5
# 24             4    431534        1    prior             5
# 25             4    431534        1    prior             5
# 26             4    431534        1    prior             5
# 27             4    431534        1    prior             5
# 28             4    431534        1    prior             5
# 29             5   3367565        1    prior             6
# 30             5   3367565        1    prior             6
# 31             5   3367565        1    prior             6
# 32             5   3367565        1    prior             6
# 33             6    550135        1    prior             7
# 34             6    550135        1    prior             7
# 35             6    550135        1    prior             7
# 36             6    550135        1    prior             7
# 37             6    550135        1    prior             7
# 38             7   3108588        1    prior             8
# 39             7   3108588        1    prior             8
# 40             7   3108588        1    prior             8
# 41             7   3108588        1    prior             8
# 42             7   3108588        1    prior             8
# 43             7   3108588        1    prior             8
# 44             8   2295261        1    prior             9
# 45             8   2295261        1    prior             9
# 46             8   2295261        1    prior             9
# 47             8   2295261        1    prior             9
# 48             8   2295261        1    prior             9
# 49             8   2295261        1    prior             9
# 50             9   2550362        1    prior            10
# 51             9   2550362        1    prior            10
# 52             9   2550362        1    prior            10
# 53             9   2550362        1    prior            10
# 54             9   2550362        1    prior            10
# 55             9   2550362        1    prior            10
# 56             9   2550362        1    prior            10
# 57             9   2550362        1    prior            10
# 58             9   2550362        1    prior            10
# 59            11   2168274        2    prior             1
# 60            11   2168274        2    prior             1
# 61            11   2168274        2    prior             1
# 62            11   2168274        2    prior             1
# 63            11   2168274        2    prior             1
# 64            11   2168274        2    prior             1
# 65            11   2168274        2    prior             1
# 66            11   2168274        2    prior             1
# 67            11   2168274        2    prior             1
# 68            11   2168274        2    prior             1
# 69            11   2168274        2    prior             1
# 70            11   2168274        2    prior             1
# 71            11   2168274        2    prior             1
# 72            12   1501582        2    prior             2
# 73            12   1501582        2    prior             2
# 74            12   1501582        2    prior             2
# 75            12   1501582        2    prior             2
# 76            12   1501582        2    prior             2
# 77            12   1501582        2    prior             2
# 78            13   1901567        2    prior             3
# 79            13   1901567        2    prior             3
# 80            13   1901567        2    prior             3
# 81            13   1901567        2    prior             3
# 82            13   1901567        2    prior             3
# 83            14    738281        2    prior             4
# 84            14    738281        2    prior             4
# 85            14    738281        2    prior             4
# 86            14    738281        2    prior             4
# 87            14    738281        2    prior             4
# 88            14    738281        2    prior             4
# 89            14    738281        2    prior             4
# 90            14    738281        2    prior             4
# 91            14    738281        2    prior             4
# 92            14    738281        2    prior             4
# 93            14    738281        2    prior             4
# 94            14    738281        2    prior             4
# 95            14    738281        2    prior             4
# 96            15   1673511        2    prior             5
# 97            15   1673511        2    prior             5
# 98            15   1673511        2    prior             5
# 99            15   1673511        2    prior             5
#
#     orders_days_of_week  order_hour_of_day  days_since_prior_order  \
# 0                     2                  8                     NaN
# 1                     2                  8                     NaN
# 2                     2                  8                     NaN
# 3                     2                  8                     NaN
# 4                     2                  8                     NaN
# 5                     3                  7                    15.0
# 6                     3                  7                    15.0
# 7                     3                  7                    15.0
# 8                     3                  7                    15.0
# 9                     3                  7                    15.0
# 10                    3                  7                    15.0
# 11                    3                 12                    21.0
# 12                    3                 12                    21.0
# 13                    3                 12                    21.0
# 14                    3                 12                    21.0
# 15                    3                 12                    21.0
# 16                    4                  7                    29.0
# 17                    4                  7                    29.0
# 18                    4                  7                    29.0
# 19                    4                  7                    29.0
# 20                    4                  7                    29.0
# 21                    4                 15                    28.0
# 22                    4                 15                    28.0
# 23                    4                 15                    28.0
# 24                    4                 15                    28.0
# 25                    4                 15                    28.0
# 26                    4                 15                    28.0
# 27                    4                 15                    28.0
# 28                    4                 15                    28.0
# 29                    2                  7                    19.0
# 30                    2                  7                    19.0
# 31                    2                  7                    19.0
# 32                    2                  7                    19.0
# 33                    1                  9                    20.0
# 34                    1                  9                    20.0
# 35                    1                  9                    20.0
# 36                    1                  9                    20.0
# 37                    1                  9                    20.0
# 38                    1                 14                    14.0
# 39                    1                 14                    14.0
# 40                    1                 14                    14.0
# 41                    1                 14                    14.0
# 42                    1                 14                    14.0
# 43                    1                 14                    14.0
# 44                    1                 16                     0.0
# 45                    1                 16                     0.0
# 46                    1                 16                     0.0
# 47                    1                 16                     0.0
# 48                    1                 16                     0.0
# 49                    1                 16                     0.0
# 50                    4                  8                    30.0
# 51                    4                  8                    30.0
# 52                    4                  8                    30.0
# 53                    4                  8                    30.0
# 54                    4                  8                    30.0
# 55                    4                  8                    30.0
# 56                    4                  8                    30.0
# 57                    4                  8                    30.0
# 58                    4                  8                    30.0
# 59                    2                 11                     NaN
# 60                    2                 11                     NaN
# 61                    2                 11                     NaN
# 62                    2                 11                     NaN
# 63                    2                 11                     NaN
# 64                    2                 11                     NaN
# 65                    2                 11                     NaN
# 66                    2                 11                     NaN
# 67                    2                 11                     NaN
# 68                    2                 11                     NaN
# 69                    2                 11                     NaN
# 70                    2                 11                     NaN
# 71                    2                 11                     NaN
# 72                    5                 10                    10.0
# 73                    5                 10                    10.0
# 74                    5                 10                    10.0
# 75                    5                 10                    10.0
# 76                    5                 10                    10.0
# 77                    5                 10                    10.0
# 78                    1                 10                     3.0
# 79                    1                 10                     3.0
# 80                    1                 10                     3.0
# 81                    1                 10                     3.0
# 82                    1                 10                     3.0
# 83                    2                 10                     8.0
# 84                    2                 10                     8.0
# 85                    2                 10                     8.0
# 86                    2                 10                     8.0
# 87                    2                 10                     8.0
# 88                    2                 10                     8.0
# 89                    2                 10                     8.0
# 90                    2                 10                     8.0
# 91                    2                 10                     8.0
# 92                    2                 10                     8.0
# 93                    2                 10                     8.0
# 94                    2                 10                     8.0
# 95                    2                 10                     8.0
# 96                    3                 11                     8.0
# 97                    3                 11                     8.0
# 98                    3                 11                     8.0
# 99                    3                 11                     8.0
#
#     first_time_customers  product_id  ...  \
# 0                   True         196  ...
# 1                   True       14084  ...
# 2                   True       12427  ...
# 3                   True       26088  ...
# 4                   True       26405  ...
# 5                  False         196  ...
# 6                  False       10258  ...
# 7                  False       12427  ...
# 8                  False       13176  ...
# 9                  False       26088  ...
# 10                 False       13032  ...
# 11                 False         196  ...
# 12                 False       12427  ...
# 13                 False       10258  ...
# 14                 False       25133  ...
# 15                 False       30450  ...
# 16                 False         196  ...
# 17                 False       12427  ...
# 18                 False       10258  ...
# 19                 False       25133  ...
# 20                 False       26405  ...
# 21                 False         196  ...
# 22                 False       12427  ...
# 23                 False       10258  ...
# 24                 False       25133  ...
# 25                 False       10326  ...
# 26                 False       17122  ...
# 27                 False       41787  ...
# 28                 False       13176  ...
# 29                 False         196  ...
# 30                 False       12427  ...
# 31                 False       10258  ...
# 32                 False       25133  ...
# 33                 False         196  ...
# 34                 False       10258  ...
# 35                 False       12427  ...
# 36                 False       25133  ...
# 37                 False       13032  ...
# 38                 False       12427  ...
# 39                 False         196  ...
# 40                 False       10258  ...
# 41                 False       25133  ...
# 42                 False       46149  ...
# 43                 False       49235  ...
# 44                 False       49235  ...
# 45                 False       46149  ...
# 46                 False       25133  ...
# 47                 False         196  ...
# 48                 False       10258  ...
# 49                 False       12427  ...
# 50                 False         196  ...
# 51                 False       46149  ...
# 52                 False       39657  ...
# 53                 False       38928  ...
# 54                 False       25133  ...
# 55                 False       10258  ...
# 56                 False       35951  ...
# 57                 False       13032  ...
# 58                 False       12427  ...
# 59                  True       32792  ...
# 60                  True       47766  ...
# 61                  True       20574  ...
# 62                  True       12000  ...
# 63                  True       48110  ...
# 64                  True       22474  ...
# 65                  True       16589  ...
# 66                  True       35917  ...
# 67                  True       27344  ...
# 68                  True       30489  ...
# 69                  True       27966  ...
# 70                  True       13176  ...
# 71                  True       45066  ...
# 72                 False       16797  ...
# 73                 False       47526  ...
# 74                 False        8479  ...
# 75                 False       47766  ...
# 76                 False       19051  ...
# 77                 False        8138  ...
# 78                 False       47766  ...
# 79                 False       32792  ...
# 80                 False       20574  ...
# 81                 False        7781  ...
# 82                 False       28874  ...
# 83                 False       49451  ...
# 84                 False       32792  ...
# 85                 False       32139  ...
# 86                 False       34688  ...
# 87                 False       36735  ...
# 88                 False       37646  ...
# 89                 False       22829  ...
# 90                 False       24852  ...
# 91                 False       47209  ...
# 92                 False       33276  ...
# 93                 False       45613  ...
# 94                 False        9681  ...
# 95                 False       21150  ...
# 96                 False       47144  ...
# 97                 False        5322  ...
# 98                 False       17224  ...
# 99                 False       38656  ...
#
#                                          product_name  aisle_id department_id  \
# 0                                                Soda        77             7
# 1             Organic Unsweetened Vanilla Almond Milk        91            16
# 2                                 Original Beef Jerky        23            19
# 3                          Aged White Cheddar Popcorn        23            19
# 4                    XL Pick-A-Size Paper Towel Rolls        54            17
# 5                                                Soda        77             7
# 6                                          Pistachios       117            19
# 7                                 Original Beef Jerky        23            19
# 8                              Bag of Organic Bananas        24             4
# 9                          Aged White Cheddar Popcorn        23            19
# 10                              Cinnamon Toast Crunch       121            14
# 11                                               Soda        77             7
# 12                                Original Beef Jerky        23            19
# 13                                         Pistachios       117            19
# 14                              Organic String Cheese        21            16
# 15                               Creamy Almond Butter        88            13
# 16                                               Soda        77             7
# 17                                Original Beef Jerky        23            19
# 18                                         Pistachios       117            19
# 19                              Organic String Cheese        21            16
# 20                   XL Pick-A-Size Paper Towel Rolls        54            17
# 21                                               Soda        77             7
# 22                                Original Beef Jerky        23            19
# 23                                         Pistachios       117            19
# 24                              Organic String Cheese        21            16
# 25                                Organic Fuji Apples        24             4
# 26                                  Honeycrisp Apples        24             4
# 27                                     Bartlett Pears        24             4
# 28                             Bag of Organic Bananas        24             4
# 29                                               Soda        77             7
# 30                                Original Beef Jerky        23            19
# 31                                         Pistachios       117            19
# 32                              Organic String Cheese        21            16
# 33                                               Soda        77             7
# 34                                         Pistachios       117            19
# 35                                Original Beef Jerky        23            19
# 36                              Organic String Cheese        21            16
# 37                              Cinnamon Toast Crunch       121            14
# 38                                Original Beef Jerky        23            19
# 39                                               Soda        77             7
# 40                                         Pistachios       117            19
# 41                              Organic String Cheese        21            16
# 42                                  Zero Calorie Cola        77             7
# 43                                Organic Half & Half        53            16
# 44                                Organic Half & Half        53            16
# 45                                  Zero Calorie Cola        77             7
# 46                              Organic String Cheese        21            16
# 47                                               Soda        77             7
# 48                                         Pistachios       117            19
# 49                                Original Beef Jerky        23            19
# 50                                               Soda        77             7
# 51                                  Zero Calorie Cola        77             7
# 52                             Milk Chocolate Almonds        45            19
# 53                           0% Greek Strained Yogurt       120            16
# 54                              Organic String Cheese        21            16
# 55                                         Pistachios       117            19
# 56                    Organic Unsweetened Almond Milk        91            16
# 57                              Cinnamon Toast Crunch       121            14
# 58                                Original Beef Jerky        23            19
# 59                     Chipotle Beef & Pork Realstick        23            19
# 60                                    Organic Avocado        24             4
# 61                                     Roasted Turkey        96            20
# 62           Baked Organic Sea Salt Crunchy Pea Snack        72            13
# 63            Thin Stackers Brown Rice Lightly Salted        78            19
# 64                     Cheddar Bunnies Snack Crackers        78            19
# 65                                     Plantain Chips       107            19
# 66                   Organic Just Concord Grape Juice        98             7
# 67                               Uncured Genoa Salami        96            20
# 68                                    Original Hummus        67            20
# 69                                Organic Raspberries       123             4
# 70                             Bag of Organic Bananas        24             4
# 71                                   Honeycrisp Apple        24             4
# 72                                       Strawberries        24             4
# 73                                    Goat Cheese Log        21            16
# 74              Original Black Box Tablewater Cracker        78            19
# 75                                    Organic Avocado        24             4
# 76               Pita Chips, Simply Naked, Party Size       107            19
# 77                                 Traditional Hummus        67            20
# 78                                    Organic Avocado        24             4
# 79                     Chipotle Beef & Pork Realstick        23            19
# 80                                     Roasted Turkey        96            20
# 81  Organic Sticks Low Moisture Part Skim Mozzarel...        21            16
# 82                                 Carrot Ginger Soup         1            20
# 83                              Artichoke Spinach Dip        67            20
# 84                     Chipotle Beef & Pork Realstick        23            19
# 85                            Hommus Classic Original        67            20
# 86  Good Belly Probiotics Juice Drink Blueberry Ac...        31             7
# 87              Organic Roasted Sliced Chicken Breast        96            20
# 88                                Organic Gala Apples        24             4
# 89          Multigrain Flax Seeded Flatbread Crackers        78            19
# 90                                             Banana        24             4
# 91                               Organic Hass Avocado        24             4
# 92                              Kalamata Olive Spread        67            20
# 93                                           Pad Thai        38             1
# 94  Chicken Tikka Masala with Cumin Infused Basmat...        38             1
# 95                            Fire Grilled Steak Bowl        38             1
# 96     Unsweetened Original Almond Breeze Almond Milk        91            16
# 97  Gluten Free Dark Chocolate Chunk Chewy with a ...         3            19
# 98                   Oats & Honey Gluten Free Granola         3            19
# 99  Gluten Free Peanut Butter Dark Chocolate Chewy...         3            19
#
#     prices  match    price_range_loc     busiest_day    busiest_days  \
# 0      9.0   both  Mid-range product  Regularly busy  Regularly busy
# 1     12.5   both  Mid-range product  Regularly busy  Regularly busy
# 2      4.4   both  Low-range product  Regularly busy  Regularly busy
# 3      4.7   both  Low-range product  Regularly busy  Regularly busy
# 4      1.0   both  Low-range product  Regularly busy  Regularly busy
# 5      9.0   both  Mid-range product  Regularly busy    Slowest Days
# 6      3.0   both  Low-range product  Regularly busy    Slowest Days
# 7      4.4   both  Low-range product  Regularly busy    Slowest Days
# 8     10.3   both  Mid-range product  Regularly busy    Slowest Days
# 9      4.7   both  Low-range product  Regularly busy    Slowest Days
# 10     4.0   both  Low-range product  Regularly busy    Slowest Days
# 11     9.0   both  Mid-range product  Regularly busy    Slowest Days
# 12     4.4   both  Low-range product  Regularly busy    Slowest Days
# 13     3.0   both  Low-range product  Regularly busy    Slowest Days
# 14     8.6   both  Mid-range product  Regularly busy    Slowest Days
# 15     3.2   both  Low-range product  Regularly busy    Slowest Days
# 16     9.0   both  Mid-range product       Least Day    Slowest Days
# 17     4.4   both  Low-range product       Least Day    Slowest Days
# 18     3.0   both  Low-range product       Least Day    Slowest Days
# 19     8.6   both  Mid-range product       Least Day    Slowest Days
# 20     1.0   both  Low-range product       Least Day    Slowest Days
# 21     9.0   both  Mid-range product       Least Day    Slowest Days
# 22     4.4   both  Low-range product       Least Day    Slowest Days
# 23     3.0   both  Low-range product       Least Day    Slowest Days
# 24     8.6   both  Mid-range product       Least Day    Slowest Days
# 25     2.7   both  Low-range product       Least Day    Slowest Days
# 26    14.0   both  Mid-range product       Least Day    Slowest Days
# 27     5.0   both  Low-range product       Least Day    Slowest Days
# 28    10.3   both  Mid-range product       Least Day    Slowest Days
# 29     9.0   both  Mid-range product  Regularly busy  Regularly busy
# 30     4.4   both  Low-range product  Regularly busy  Regularly busy
# 31     3.0   both  Low-range product  Regularly busy  Regularly busy
# 32     8.6   both  Mid-range product  Regularly busy  Regularly busy
# 33     9.0   both  Mid-range product  Regularly busy    Busiest Days
# 34     3.0   both  Low-range product  Regularly busy    Busiest Days
# 35     4.4   both  Low-range product  Regularly busy    Busiest Days
# 36     8.6   both  Mid-range product  Regularly busy    Busiest Days
# 37     4.0   both  Low-range product  Regularly busy    Busiest Days
# 38     4.4   both  Low-range product  Regularly busy    Busiest Days
# 39     9.0   both  Mid-range product  Regularly busy    Busiest Days
# 40     3.0   both  Low-range product  Regularly busy    Busiest Days
# 41     8.6   both  Mid-range product  Regularly busy    Busiest Days
# 42    13.4   both  Mid-range product  Regularly busy    Busiest Days
# 43     1.8   both  Low-range product  Regularly busy    Busiest Days
# 44     1.8   both  Low-range product  Regularly busy    Busiest Days
# 45    13.4   both  Mid-range product  Regularly busy    Busiest Days
# 46     8.6   both  Mid-range product  Regularly busy    Busiest Days
# 47     9.0   both  Mid-range product  Regularly busy    Busiest Days
# 48     3.0   both  Low-range product  Regularly busy    Busiest Days
# 49     4.4   both  Low-range product  Regularly busy    Busiest Days
# 50     9.0   both  Mid-range product       Least Day    Slowest Days
# 51    13.4   both  Mid-range product       Least Day    Slowest Days
# 52     6.8   both  Mid-range product       Least Day    Slowest Days
# 53    12.6   both  Mid-range product       Least Day    Slowest Days
# 54     8.6   both  Mid-range product       Least Day    Slowest Days
# 55     3.0   both  Low-range product       Least Day    Slowest Days
# 56     1.3   both  Low-range product       Least Day    Slowest Days
# 57     4.0   both  Low-range product       Least Day    Slowest Days
# 58     4.4   both  Low-range product       Least Day    Slowest Days
# 59     5.2   both  Mid-range product  Regularly busy  Regularly busy
# 60     6.3   both  Mid-range product  Regularly busy  Regularly busy
# 61     2.3   both  Low-range product  Regularly busy  Regularly busy
# 62    10.9   both  Mid-range product  Regularly busy  Regularly busy
# 63     2.7   both  Low-range product  Regularly busy  Regularly busy
# 64     4.1   both  Low-range product  Regularly busy  Regularly busy
# 65     5.0   both  Low-range product  Regularly busy  Regularly busy
# 66     9.4   both  Mid-range product  Regularly busy  Regularly busy
# 67    14.8   both  Mid-range product  Regularly busy  Regularly busy
# 68     7.5   both  Mid-range product  Regularly busy  Regularly busy
# 69     4.4   both  Low-range product  Regularly busy  Regularly busy
# 70    10.3   both  Mid-range product  Regularly busy  Regularly busy
# 71     2.5   both  Low-range product  Regularly busy  Regularly busy
# 72     1.3   both  Low-range product  Regularly busy  Regularly busy
# 73     2.0   both  Low-range product  Regularly busy  Regularly busy
# 74     3.5   both  Low-range product  Regularly busy  Regularly busy
# 75     6.3   both  Mid-range product  Regularly busy  Regularly busy
# 76     3.9   both  Low-range product  Regularly busy  Regularly busy
# 77     2.0   both  Low-range product  Regularly busy  Regularly busy
# 78     6.3   both  Mid-range product  Regularly busy    Busiest Days
# 79     5.2   both  Mid-range product  Regularly busy    Busiest Days
# 80     2.3   both  Low-range product  Regularly busy    Busiest Days
# 81     6.6   both  Mid-range product  Regularly busy    Busiest Days
# 82     6.2   both  Mid-range product  Regularly busy    Busiest Days
# 83     7.1   both  Mid-range product  Regularly busy  Regularly busy
# 84     5.2   both  Mid-range product  Regularly busy  Regularly busy
# 85     7.5   both  Mid-range product  Regularly busy  Regularly busy
# 86     5.8   both  Mid-range product  Regularly busy  Regularly busy
# 87     8.9   both  Mid-range product  Regularly busy  Regularly busy
# 88     9.1   both  Mid-range product  Regularly busy  Regularly busy
# 89     5.5   both  Mid-range product  Regularly busy  Regularly busy
# 90    12.3   both  Mid-range product  Regularly busy  Regularly busy
# 91     4.0   both  Low-range product  Regularly busy  Regularly busy
# 92    10.8   both  Mid-range product  Regularly busy  Regularly busy
# 93    12.6   both  Mid-range product  Regularly busy  Regularly busy
# 94     2.0   both  Low-range product  Regularly busy  Regularly busy
# 95     5.9   both  Mid-range product  Regularly busy  Regularly busy
# 96    14.0   both  Mid-range product  Regularly busy    Slowest Days
# 97     2.9   both  Low-range product  Regularly busy    Slowest Days
# 98     1.6   both  Low-range product  Regularly busy    Slowest Days
# 99     3.4   both  Low-range product  Regularly busy    Slowest Days
#
#    busiest_period_of_day max_order
# 0         Average orders        10
# 1         Average orders        10
# 2         Average orders        10
# 3         Average orders        10
# 4         Average orders        10
# 5         Average orders        10
# 6         Average orders        10
# 7         Average orders        10
# 8         Average orders        10
# 9         Average orders        10
# 10        Average orders        10
# 11           Most orders        10
# 12           Most orders        10
# 13           Most orders        10
# 14           Most orders        10
# 15           Most orders        10
# 16        Average orders        10
# 17        Average orders        10
# 18        Average orders        10
# 19        Average orders        10
# 20        Average orders        10
# 21           Most orders        10
# 22           Most orders        10
# 23           Most orders        10
# 24           Most orders        10
# 25           Most orders        10
# 26           Most orders        10
# 27           Most orders        10
# 28           Most orders        10
# 29        Average orders        10
# 30        Average orders        10
# 31        Average orders        10
# 32        Average orders        10
# 33           Most orders        10
# 34           Most orders        10
# 35           Most orders        10
# 36           Most orders        10
# 37           Most orders        10
# 38           Most orders        10
# 39           Most orders        10
# 40           Most orders        10
# 41           Most orders        10
# 42           Most orders        10
# 43           Most orders        10
# 44           Most orders        10
# 45           Most orders        10
# 46           Most orders        10
# 47           Most orders        10
# 48           Most orders        10
# 49           Most orders        10
# 50        Average orders        10
# 51        Average orders        10
# 52        Average orders        10
# 53        Average orders        10
# 54        Average orders        10
# 55        Average orders        10
# 56        Average orders        10
# 57        Average orders        10
# 58        Average orders        10
# 59           Most orders        14
# 60           Most orders        14
# 61           Most orders        14
# 62           Most orders        14
# 63           Most orders        14
# 64           Most orders        14
# 65           Most orders        14
# 66           Most orders        14
# 67           Most orders        14
# 68           Most orders        14
# 69           Most orders        14
# 70           Most orders        14
# 71           Most orders        14
# 72           Most orders        14
# 73           Most orders        14
# 74           Most orders        14
# 75           Most orders        14
# 76           Most orders        14
# 77           Most orders        14
# 78           Most orders        14
# 79           Most orders        14
# 80           Most orders        14
# 81           Most orders        14
# 82           Most orders        14
# 83           Most orders        14
# 84           Most orders        14
# 85           Most orders        14
# 86           Most orders        14
# 87           Most orders        14
# 88           Most orders        14
# 89           Most orders        14
# 90           Most orders        14
# 91           Most orders        14
# 92           Most orders        14
# 93           Most orders        14
# 94           Most orders        14
# 95           Most orders        14
# 96           Most orders        14
# 97           Most orders        14
# 98           Most orders        14
# 99           Most orders        14
#
# [100 rows x 22 columns]

# %% [markdown]
# <H4>5. Deriving Columns with loc()</H4>

# %%
# New column is created,  flag customers who meet the criteria as 'loyal'
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] >10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check value counts to check the frequency of the new loyalty flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Observation -Most customers fall into the 'Regular customer' category

# %%
# Check output 
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %%
# Export dataframe with newly derived columns
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_derived_new_variables.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 23)
