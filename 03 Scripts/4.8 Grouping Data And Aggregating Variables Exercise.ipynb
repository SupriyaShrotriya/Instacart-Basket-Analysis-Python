# %% [markdown]
# <H1>Importing Libraries</H1>

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Create path
path = r'C:\Users\supri\Desktop\Supriya\DataAnalysis\Project\Data Immersion\Achievement 1-2\Instacart_Basket_Analysis'

# %%
# Import dataframe including newly derived columns from the previous exercise
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged_derived_new_variables.pkl'))

# %%
# Check output
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# <H3>2.Find the aggregated mean of the “order_number” column grouped by “department_id”  for the entire dataframe</H3>

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# <H4>3 Observation - Compared to the subset, the full dataframe includes all 'department_id' values. Also, the mean values for department IDs found in the subset have changed—some increased, while others decreased. For instance, department ID 4 had a mean of 18.825780 in the subset, but in the full dataset, it is 17.811403.</H4>

# %% [markdown]
# <H3>4.Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.</H3>

# %%
# These operations were already performed on the dataframe during the previous exercise
#Can be confirmed by the presence of the 'max_orders' and 'loyalty_flag' columns already in place

# %%
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
# ...

# %%
# Check loyalty flags frequency
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# <H3>05. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.</H3>

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# <H4>Observation -On average, new customers spend the most money on their purchases, followed by regular customers, and lastly loyal customers.</H4>

# %% [markdown]
# <H3>06. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”</H3>

# %%
# Create a new column for the average price of a product
ords_prods_merge['average_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
# Check the output
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
# ...

# %%
# Setting the spending_flag with the criteria
ords_prods_merge.loc[ords_prods_merge['average_price']<10,'spending_flag']='Low_spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price']>= 10, 'spending_flag'] = 'High_spender'

# %%
# Check the frequency of the spending-flag
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low_spender     31770614
# High_spender      634245
# Name: count, dtype: int64

# %% [markdown]
# <H4>Observation - Low numbers of high spenders compared to the Low spenders</H4>

# %% [markdown]
# <H3>07. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a 'Non-frequent customer'
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a 'Regular customer'
# If the median is lower than or equal to 10, then the customer should be labeled a 'Frequent customer'</H3>

# %%
# Create a new column for customer frequency flags based on the median values from 'days_since_prior_order' column
ords_prods_merge['customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
# Check output
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              0   2539329        1    prior             1
# 2              0   2539329        1    prior             1
# 3              0   2539329        1    prior             1
# 4              0   2539329        1    prior             1
# 5              1   2398795        1    prior             2
# 6              1   2398795        1    prior             2
# 7              1   2398795        1    prior             2
# 8              1   2398795        1    prior             2
# 9              1   2398795        1    prior             2
# 10             1   2398795        1    prior             2
# 11             2    473747        1    prior             3
# 12             2    473747        1    prior             3
# 13             2    473747        1    prior             3
# 14             2    473747        1    prior             3
# ...

# %%
# Create frequency_flag based on the criteria
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['customer_frequency'] > 10) & (ords_prods_merge['customer_frequency'] <=20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check the frequency for the frequency_flag
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
#Check the head for the new columns
ords_prods_merge[['user_id', 'customer_frequency', 'frequency_flag']].head(100)
# Out:
#     user_id  customer_frequency         frequency_flag
# 0         1                20.5  Non-frequent customer
# 1         1                20.5  Non-frequent customer
# 2         1                20.5  Non-frequent customer
# 3         1                20.5  Non-frequent customer
# 4         1                20.5  Non-frequent customer
# ..      ...                 ...                    ...
# 95        2                13.0       Regular customer
# 96        2                13.0       Regular customer
# 97        2                13.0       Regular customer
# 98        2                13.0       Regular customer
# 99        2                13.0       Regular customer
#
# [100 rows x 3 columns]

# %%
#Check shape 
ords_prods_merge.shape
# Out:
# (32404859, 27)

# %%
# Export dataframe as a pickle file
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_derived_new_variables_aggregated.pkl'))
